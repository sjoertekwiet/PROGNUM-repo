# %% [markdown]
# Answers for Week 1
#
# * Name: Sjoerd Kiewiet
# * Username: skiewiet
# * Student s-number: s6463509
# * Group (AS1, etc.): AS5

# %% [markdown]
# x=22/7

# %% [markdown]
# $$y = \frac{sin(x)}{x}$$

# %% [markdown]
# pi = 22/7  # Processed on Jupyter Hub

# %% [markdown]
# Question 1.3:

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print(x)
# Out:
# 720

# %% [markdown]
# Question 1.4:

# %%
from scipy.constants import h
print(h)
# Out:
# 6.62607015e-34

# %%
E=h*2.42e28
print(E)
# Out:
# 1.6035089763e-05

# %% [markdown]
# Question 1.5:

# %%
from scipy.constants import G
print(G)

# %%
F=G*7.342e22*5.9722e24/(385000600**2)
print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# Question 1.6:

# %%
from scipy.constants import G, pi, au
x= (4*pi**2*au**3)/(G*(365*24*3600)**2)
print(x)
# Out:
# 1.9912098654808826e+30

# %% [markdown]
# Question 1.7:

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %%
x1 = 10
x2 = 22/7
print(x1, x2, sep=" ===== ")
print(x1, end="")
print(x2, end="Yes\n\n")
print("The end")
# Out:
# 10 ===== 3.142857142857143
# 103.142857142857143Yes
#
# The end

# %% [markdown]
# Question 1.8:

# %% [markdown]
# ![sho.png](attachment:sho.png)

# %% [markdown]
# Question 1.10:

# %% [markdown]
# ![scre.png](attachment:scre.png)

# %% [markdown]
# Question 1.11

# %% [markdown]
# ![Screenshot%20from%202026-02-13%2013-40-41.png](attachment:Screenshot%20from%202026-02-13%2013-40-41.png)

# %% [markdown]
# Question 1.12:

# %% [markdown]
# ![Screenshot%20from%202026-02-13%2013-52-04.png](attachment:Screenshot%20from%202026-02-13%2013-52-04.png)
