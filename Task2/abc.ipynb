# %%
from math import *
a=float(input("a="))
b=float(input("b="))
c=float(input("c="))
D=b**2-4*a*c
x1=((-b+(b**2-4*a*c)**0.5)/2*a)
x2=((-b-(b**2-4*a*c)**0.5)/2*a)
if D>0:
    print(f"The roots are x1={x1} and x2={x2}")
elif D==0:
    print(f"The root is x={x1}")
else:
    print("There are no roots")
# Out:
# a=1
# b=0
# c=-16
# The roots are x1=4.0 and x2=-4.0
